# %%
import pandas as pd
import glob
import fnmatch

# %%
# only select files related to course or user data
filePath = ('data/*.csv')
files = []
for fp in filePath:
    for filename in glob.glob(fp):
        print filename
        files.append(filename)
# Out:
# /
# /
# data
# dataAnalysis.ipynb
# extractData.ipynb
# README.md
# .

# %%
def printFile(filePath):
    print filePath
    with open(filePath,'r') as f:
        data = pd.read_csv(f,delim_whitespace=True,header=None,error_bad_lines=False)
        print "summary:\n",data.describe(),"\n\nhead:"
        print "==========================================\n"
        print data.head()
        return data

# %%
printFile("../data/course_article.csv")
# Out:
# ../data/course_article.csv
# Skipping line 2: expected 3339 fields, saw 3816
# Skipping line 3: expected 3339 fields, saw 6390
# Skipping line 4: expected 3339 fields, saw 6478
# Skipping line 6: expected 3339 fields, saw 6962
# Skipping line 7: expected 3339 fields, saw 8671
# Skipping line 8: expected 3339 fields, saw 4065
# Skipping line 9: expected 3339 fields, saw 5382
# Skipping line 10: expected 3339 fields, saw 4228
# Skipping line 11: expected 3339 fields, saw 5831
# Skipping line 13: expected 3339 fields, saw 5858
# Skipping line 14: expected 3339 fields, saw 6363
# Skipping line 15: expected 3339 fields, saw 5392
# Skipping line 16: expected 3339 fields, saw 4866
# Skipping line 17: expected 3339 fields, saw 6661
# Skipping line 18: expected 3339 fields, saw 3442
# Skipping line 19: expected 3339 fields, saw 6555
# Skipping line 20: expected 3339 fields, saw 5512
# Skipping line 21: expected 3339 fields, saw 4309
# Skipping line 22: expected 3339 fields, saw 3547
# Skipping line 23: expected 3339 fields, saw 4547
# Skipping line 24: expected 3339 fields, saw 5003
# Skipping line 25: expected 3339 fields, saw 5285
# Skipping line 26: expected 3339 fields, saw 5831
# Skipping line 27: expected 3339 fields, saw 5957
# Skipping line 28: expected 3339 fields, saw 5708
# Skipping line 30: expected 3339 fields, saw 11624
# Skipping line 32: expected 3339 fields, saw 5157
# Skipping line 33: expected 3339 fields, saw 6153
# Skipping line 34: expected 3339 fields, saw 4942
# Skipping line 35: expected 3339 fields, saw 9509
# Skipping line 36: expected 3339 fields, saw 6573
# Skipping line 37: expected 3339 fields, saw 5408
# Skipping line 38: expected 3339 fields, saw 5374
# Skipping line 40: expected 3339 fields, saw 8218
# Skipping line 42: expected 3339 fields, saw 8507
# Skipping line 43: expected 3339 fields, saw 5005
# Skipping line 44: expected 3339 fields, saw 3876
# Skipping line 45: expected 3339 fields, saw 5238
# Skipping line 46: expected 3339 fields, saw 6516
# Skipping line 48: expected 3339 fields, saw 7092
# Skipping line 49: expected 3339 fields, saw 4784
# Skipping line 55: expected 3339 fields, saw 5344
# summary:
#              0      3336   3337   3338
# count   13.000000    1.0    1.0    1.0
# mean   260.000000  168.0  168.0  168.0
# std    105.141175    NaN    NaN    NaN
# min     15.000000  168.0  168.0  168.0
# 25%    287.000000  168.0  168.0  168.0
# 50%    303.000000  168.0  168.0  168.0
# 75%    306.000000  168.0  168.0  168.0
# max    321.000000  168.0  168.0  168.0
#
# head:
# ==========================================
#
#    0             1      2     \
# 0   319  Introduction  <span
# 1   320  Introduction  <span
# 2   321  Introduction     <p
# 3    37       Compare   Your
# 4   301      Colorful  Foods
#
#                                                 3                    4     \
# 0  id="docs-internal-guid-57781d2a-9e1b-ad61-28bb...            dir="ltr"
# 1  id="docs-internal-guid-63d58086-ad89-8ef3-7be4...            dir="ltr"
# 2                                          dir="ltr"  style="line-height:
# 3                                            Culture                 with
# 4                                             Around                  the
#
#                   5            6     \
# 0  style="line-height:           1;
# 1  style="line-height:           1;
# 2                   1;  margin-top:
# 3                 that           of
# 4                World        <span
#
#                                                 7               8     \
# 0                                        margin-top:            0pt;
# 1                                        margin-top:            0pt;
# 2                                               0pt;  margin-bottom:
# 3                                               Your          PenPal
# 4  id="docs-internal-guid-991eef08-68b5-783c-d1e4...       dir="ltr"
#
#                                                 9     ...      3329     3330  \
# 0                                     margin-bottom:  ...    you’ll  already
# 1                                     margin-bottom:  ...       NaN      NaN
# 2                                        0pt;"><span  ...       NaN      NaN
# 3                                    <p><br></p><img  ...       NaN      NaN
# 4  style="line-height:1.2;margin-top:0pt;margin-b...  ...       NaN      NaN
#
#    3331       3332 3333  3334                  3335   3336   3337   3338
# 0  have  something   to  talk  about!</span></span>  168.0  168.0  168.0
# 1   NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 2   NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 3   NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 4   NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
#
# [5 rows x 3339 columns]
#     0             1        2     \
# 0    319  Introduction    <span
# 1    320  Introduction    <span
# 2    321  Introduction       <p
# 3     37       Compare     Your
# 4    301      Colorful    Foods
# 5    260    Reflection    <span
# 6    302         Where     Does
# 7    306         Let's      Eat
# 8     15             A    World
# 9    303           Eat   Greens
# 10   304     Celebrate  Diverse
# 11   305            At      The
# 12   287           The    World
#
#                                                  3                    4     \
# 0   id="docs-internal-guid-57781d2a-9e1b-ad61-28bb...            dir="ltr"
# 1   id="docs-internal-guid-63d58086-ad89-8ef3-7be4...            dir="ltr"
# 2                                           dir="ltr"  style="line-height:
# 3                                             Culture                 with
# 4                                              Around                  the
# 5   id="docs-internal-guid-d1caf36d-8e8b-f621-3117...            dir="ltr"
# 6                                                Food                 Come
# 7                                             Healthy             Together
# 8                                                  of                 News
# 9                                              First!                   <p
# 10                                             Foods!                   <p
# 11                                            Grocery                Store
# 12                                            Through                   My
#
#                                                  5     \
# 0                                 style="line-height:
# 1                                 style="line-height:
# 2                                                  1;
# 3                                                that
# 4                                               World
# 5   style="line-height:1.2;margin-top:0pt;margin-b...
# 6                                               From?
# 7                                                  <p
# 8                                               <span
# 9                                 style="line-height:
# 10                                style="line-height:
# 11                                                 <p
# 12                                               Eyes
#
#                                                  6     \
# 0                                                  1;
# 1                                                  1;
# 2                                         margin-top:
# 3                                                  of
# 4                                               <span
# 5                                   style="font-size:
# 6                                                  <p
# 7                                 style="line-height:
# 8   id="docs-internal-guid-57afab52-10ff-cb57-b653...
# 9                                   22.2222px;">Lorem
# 10                                  22.2222px;">Lorem
# 11                                style="line-height:
# 12                                              <span
#
#                                                  7     \
# 0                                         margin-top:
# 1                                         margin-top:
# 2                                                0pt;
# 3                                                Your
# 4   id="docs-internal-guid-991eef08-68b5-783c-d1e4...
# 5                                          18.6667px;
# 6                                 style="line-height:
# 7                                   22.2222px;">Lorem
# 8                                           dir="ltr"
# 9                                               ipsum
# 10                                              ipsum
# 11                                  22.2222px;">Lorem
# 12  id="docs-internal-guid-33080947-7ef6-7e38-5e7e...
#
#                                                  8     \
# 0                                                0pt;
# 1                                                0pt;
# 2                                      margin-bottom:
# 3                                              PenPal
# 4                                           dir="ltr"
# 5                                        font-family:
# 6                                   22.2222px;">Lorem
# 7                                               ipsum
# 8   style="line-height:1.38;margin-top:0pt;margin-...
# 9                                               dolor
# 10                                              dolor
# 11                                              ipsum
# 12                                          dir="ltr"
#
#                                                  9     ...      3329     3330  \
# 0                                      margin-bottom:  ...    you’ll  already
# 1                                      margin-bottom:  ...       NaN      NaN
# 2                                         0pt;"><span  ...       NaN      NaN
# 3                                     <p><br></p><img  ...       NaN      NaN
# 4   style="line-height:1.2;margin-top:0pt;margin-b...  ...       NaN      NaN
# 5                                              Arial;  ...       NaN      NaN
# 6                                               ipsum  ...       NaN      NaN
# 7                                               dolor  ...       NaN      NaN
# 8                                   style="font-size:  ...       NaN      NaN
# 9                                                 sit  ...       NaN      NaN
# 10                                                sit  ...       NaN      NaN
# 11                                              dolor  ...       NaN      NaN
# 12  style="line-height:1.2;margin-top:0pt;margin-b...  ...       NaN      NaN
#
#     3331       3332 3333  3334                  3335   3336   3337   3338
# 0   have  something   to  talk  about!</span></span>  168.0  168.0  168.0
# 1    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 2    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 3    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 4    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 5    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 6    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 7    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 8    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 9    NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 10   NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 11   NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
# 12   NaN        NaN  NaN   NaN                   NaN    NaN    NaN    NaN
#
# [13 rows x 3339 columns]

# %%
for fp in files:
    print(fp)
    data = printFile(fp)
    print(data.head())

# %%
data.columns()
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-33-31f5dce5b69f> in <module>()
# ----> 1 data.columns()
#
# TypeError: 'Index' object is not callable

# %%
data.describe()
# Out:
#         4391\t313\t701\t1
# count                 103
# unique                103
# top     3778\t289\t654\t2
# freq                    1
